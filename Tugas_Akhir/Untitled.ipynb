# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Membaca dataset
data = pd.read_csv("card_transdata.csv")  # Ganti "nama_file_dataset.csv" dengan nama file dataset Anda

# Memisahkan fitur dan label
X = data.drop("fraud", axis=1)
y = data["fraud"]

# Memisahkan data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Melatih model Naive Bayes
model = GaussianNB()
model.fit(X_train, y_train)

# Melakukan prediksi pada data uji
y_pred = model.predict(X_test)

# Membuat laporan klasifikasi
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)

# Membuat confusion matrix dan heatmap
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel("Prediksi")
plt.ylabel("Aktual")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97    182557
#          1.0       0.79      0.60      0.68     17443
#
#     accuracy                           0.95    200000
#    macro avg       0.88      0.79      0.83    200000
# weighted avg       0.95      0.95      0.95    200000

# %%
data[data["fraud"]==0].shape
# Out:
# (912597, 8)

# %%
data[data["fraud"]==1].shape
# Out:
# (87403, 8)
